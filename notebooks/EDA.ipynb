# %%
import pandas as pd
import plotly.express as px
import streamlit as st

# %%
vehicles_data = pd.read_csv('../vehicles_us.csv')
vehicles_data['manufacturer'] = vehicles_data['model'].apply(lambda x: x.split()[0])

# %%
display(car_ad_data.sample(5))
# Out:
#        price  model_year                          model  condition  cylinders  \
# 39476  28995      2019.0                  honda odyssey  excellent        6.0
# 30750  34490      2011.0                       ram 3500  excellent        6.0
# 24301   8000      2013.0                chevrolet cruze  excellent        4.0
# 48039  23900      2014.0  chevrolet silverado 1500 crew       good        8.0
# 2418    4795      2001.0       chevrolet silverado 1500       good        8.0
#
#          fuel  odometer transmission      type paint_color  is_4wd  \
# 39476     gas   42240.0    automatic  mini-van        blue     NaN
# 30750  diesel   96753.0    automatic    pickup         NaN     1.0
# 24301     gas   55200.0    automatic     sedan        grey     NaN
# 48039     gas   91844.0    automatic    pickup       white     1.0
# 2418      gas  140364.0    automatic     truck       brown     1.0
#
#       date_posted  days_listed manufacturer
# 39476  2019-02-24           40        honda
# ...

# %%
car_ad_data['fuel'].unique()
# Out:
# array(['gas', 'diesel', 'other', 'hybrid', 'electric'], dtype=object)

# %%
a = car_ad_data.groupby(['model', 'model_year'])['price'].mean().reset_index()

# %%
fig = px.scatter(a, x="model_year", y="price", color="model")
fig.show()

# %%
manufracturertypes = px.histogram(car_ad_data, x='manufacturer', color='type')
st.write(manufracturertypes)
# Out:
# 2023-07-16 01:29:07.797
# ...
#   command:
#
#     streamlit run c:\Users\vinee_xamz2lk\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
